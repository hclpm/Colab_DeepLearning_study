# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://hclpm: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@github.com/hclpm/Colab_DeepLearning_study.git
# Out:
# Cloning into 'Colab_DeepLearning_study'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (10/10), done.

# %%
cd /content/drive/MyDrive/Colab_DeepLearning_study
# Out:
# /content/drive/MyDrive/Colab_DeepLearning_study

# %%
# !git config --global user.email 'hclpm@gmail.com'
# !git config --global user.name ''

# %% [markdown]
# 초기설정: git clone 하는법

# %%
# !git clone https://hclpm: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@github.com/hclpm/Colab.git
# Out:
# Cloning into 'Colab'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.

# %%
cd /content/drive/MyDrive/Colab/Study
# Out:
# /content/drive/MyDrive/Colab/Study

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab
# Out:
# [main cf90aed] colab 2nd push
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Study/Gitsync.ipynb (92%)

# %%
# !git config --global user.email "hcleepm@gmail.com"
# !git config --global user.name "hclpm"

# %%
# !git add --all

# %%
# !git commit -m '1st push'
# Out:
# [main 2417f30] 1st push
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Study/Gitsync.ipynb (74%)

# %%
# !git push
# Out:
# fatal: The current branch main has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin main

# %%
# !git push --set-upstream origin main
# Out:
# remote: Not Found
# fatal: repository 'https://github.com/repository/hclpm/Colab.git/' not found
